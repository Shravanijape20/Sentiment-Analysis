# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravanijape20/Sentiment-Analysis/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import re
df = pd.read_csv('Sports.csv')
df.head()
# Out:
#                                                 Text     Label
# 0  The team's recent victories have raised suspic...  positive
# 1  Despite their recent loss, the team's morale r...  positive
# 2  Rumors of match-fixing have cast a shadow over...  negative
# 3  The unexpected resignation of the coach has le...  negative
# 4  Speculations about doping allegations have led...  negative

# %%
df.shape
# Out:
# (56, 2)

# %%
# Subset - if you want a sample with replacement, set replace=True
df = df.sample(30, replace=True)
# resetting index
df.reset_index(drop=True, inplace=True)
# sample dataset size
df.shape
# Out:
# (30, 2)

# %%
# positive:1 , negative:0

df['Label'].replace({'positive':1, 'negative':0}, inplace=True)
df.head()
# Out:
#                                                 Text  Label
# 0  The impact of sports on society is complex and...      1
# 1  Sports events offer a platform for showcasing ...      1
# 2  The commercialization of sports undermines the...      0
# 3  The hyper-competitiveness of sports can lead t...      0
# 4  Commercialization has turned sports into a luc...      0

# %%
# @title Label

from matplotlib import pyplot as plt
df['Label'].plot(kind='hist', bins=20, title='Label')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Distribution of Labels

import matplotlib.pyplot as plt

# Count the occurrences of each label
label_counts = df['Label'].value_counts()

# Create a pie chart
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
_ = plt.title('Distribution of Labels')

# %%
# functions to remove noise
# remove html tags
def clean_html(text):
 clean = re.compile('<.*?>')
 return re.sub(clean, '', text)
# remove brackets
def remove_brackets(text):
 return re.sub('\[[^]]*\]', '', text)
# lower the cases
def lower_cases(text):
 return text.lower()
# remove special characters
def remove_char(text):
 pattern = r'[^a-zA-z0–9\s]'
 text = re.sub(pattern, '', text)
 return text
print(df)
# Out:
#                                                  Text  Label
# 0   the impact of sports on society is complex and...      1
# 1   sports events offer a platform for showcasing ...      1
# 2   the commercialization of sports undermines the...      0
# 3   the hypercompetitiveness of sports can lead to...      0
# 4   commercialization has turned sports into a luc...      0
# 5   sports organizations must do more to address i...      0
# 6   rumors of matchfixing have cast a shadow over ...      0
# 7   sports fandom can foster a sense of community ...      1
# 8   sports organizations prioritize profits over t...      0
# 9   sports broadcasting has become saturated with ...      0
# 10  sports scholarships offer opportunities for ed...      1
# 11  corruption and bribery scandals tarnish the in...      0
# 12  sports provide a platform for social activism ...      1
# 13  participation in sports can foster lifelong fr...      1
# ...
